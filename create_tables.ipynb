# %%
import mysql.connector

# Connect to MySQL Server
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Mysql@123"
)

print("Connected to MySQL")

'''# Create a cursor to execute SQL commands
cursor = connection.cursor()

# Replace 'my_new_db' with your desired database name
cursor.execute("CREATE DATABASE txt2sql")

print("Database 'my_new_db' created successfully!")'''
# Out:
# Connected to MySQL
# '# Create a cursor to execute SQL commands\ncursor = connection.cursor()\n\n# Replace \'my_new_db\' with your desired database name\ncursor.execute("CREATE DATABASE txt2sql")\n\nprint("Database \'my_new_db\' created successfully!")'

# %% [markdown]
# ### Downloads dataset from kaggle
# - Soon after it downloads pull the files to current folder

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("olistbr/brazilian-ecommerce")
print("Path to dataset files:", path)
# kaggle datasets download -d olistbr/brazilian-ecommerce
# unzip dataset-name.zip
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import kagglehub
#       2
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("olistbr/brazilian-ecommerce")
#
# File c:\Users\Rinshi\Desktop\projects\txt2sql\.venv\Lib\site-packages\kagglehub\__init__.py:4
#       1 __version__ = "1.0.1"
#       3 import kagglehub.logger  # configures the library logger.
# ----> 4 from kagglehub import colab_cache_resolver, http_resolver, kaggle_cache_resolver, registry
#       5 from kagglehub.auth import login, whoami
#       6 from kagglehub.competition import competition_download
#
# File c:\Users\Rinshi\Desktop\projects\txt2sql\.venv\Lib\site-packages\kagglehub\colab_cache_resolver.py:5
#       2 import os
#       3 import time
# ----> 5 from kagglehub.clients import ColabClient
#       6 from kagglehub.config import is_colab_cache_disabled
#       7 from kagglehub.exceptions import BackendError, NotFoundError
#
# File c:\Users\Rinshi\Desktop\projects\txt2sql\.venv\Lib\site-packages\kagglehub\clients.py:22
#      19 from tqdm import tqdm
#      21 import kagglehub
# ---> 22 from kagglehub.cache import delete_from_cache, get_cached_archive_path
#      23 from kagglehub.config import get_kaggle_credentials
#      24 from kagglehub.datasets_enums import KaggleDatasetAdapter
#
# File c:\Users\Rinshi\Desktop\projects\txt2sql\.venv\Lib\site-packages\kagglehub\cache.py:6
#       3 from pathlib import Path
#       5 from kagglehub.config import get_cache_folder
# ----> 6 from kagglehub.handle import CompetitionHandle, DatasetHandle, ModelHandle, NotebookHandle, ResourceHandle
#       8 DATASETS_CACHE_SUBFOLDER = "datasets"
#       9 NOTEBOOKS_CACHE_SUBFOLDER = "notebooks"  # for resources under kaggle.com/code
#
# File c:\Users\Rinshi\Desktop\projects\txt2sql\.venv\Lib\site-packages\kagglehub\handle.py:6
#       3 import abc
#       4 from dataclasses import asdict, dataclass
# ----> 6 from kagglesdk.kaggle_env import get_env, get_web_endpoint
#       7 from kagglesdk.models.types.model_enums import ModelFramework
#       9 from kagglehub.enum import to_enum
#
# ImportError: cannot import name 'get_web_endpoint' from 'kagglesdk.kaggle_env' (c:\Users\Rinshi\Desktop\projects\txt2sql\.venv\Lib\site-packages\kagglesdk\kaggle_env.py)

# %%
import pandas as pd
from sqlalchemy import create_engine,  text
from sqlalchemy.exc import SQLAlchemyError
from sqlalchemy.types import Integer, Float, String

# %%
df = pd.read_csv('brazilian-ecommerce\olist_customers_dataset.csv')  # Replace with your CSV file path

# Step 2: Set up SQLAlchemy engine with your MySQL credentials
# engine = create_engine('mysql+mysqlconnector://root:Mysql@123@localhost/txt2sql')
from sqlalchemy import create_engine, text
import urllib.parse

# 1. URL-encode your password
password = urllib.parse.quote_plus("Mysql@123")

# 2. Connect to the base server (omit the database name from the URL)
base_url = f"mysql+mysqlconnector://root:{password}@localhost"
base_engine = create_engine(base_url)

# 3. Create the database if it doesn't exist
with base_engine.connect() as conn:
    # Commit is required because DB creation cannot run inside an active transaction block
    conn.execute(text("CREATE DATABASE IF NOT EXISTS txt2sql"))
    print("Database 'txt2sql' is ready!")

# 4. Now you can safely connect to the specific database
db_url = f"mysql+mysqlconnector://root:{password}@localhost/txt2sql"
engine = create_engine(db_url)

# Step 3: Write the DataFrame to a new MySQL table
df.to_sql(name='customer', con=engine, index=False, if_exists='replace')  # or 'append'

print("Data has been written to the 'my_table' table in the 'txt2sql' database.")
# Out:
# Database 'txt2sql' is ready!
# Data has been written to the 'my_table' table in the 'txt2sql' database.

# %%
df = pd.read_csv('brazilian-ecommerce\olist_order_items_dataset.csv')  # Replace with your CSV file path

# Step 2: Set up SQLAlchemy engine with your MySQL credentials
engine = create_engine(db_url)

# Step 3: Write the DataFrame to a new MySQL table
df.to_sql(name='order_items', con=engine, index=False, if_exists='replace')  # or 'append'

print("Data has been written to the 'my_table' table in the 'txt2sql' database.")
# Out:
# Data has been written to the 'my_table' table in the 'txt2sql' database.

# %%
df = pd.read_csv('brazilian-ecommerce\olist_order_payments_dataset.csv')  # Replace with your CSV file path

# Step 2: Set up SQLAlchemy engine with your MySQL credentials
engine = create_engine(db_url)

# Step 3: Write the DataFrame to a new MySQL table
df.to_sql(name='order_payments', con=engine, index=False, if_exists='replace')  # or 'append'

print("Data has been written to the 'my_table' table in the 'txt2sql' database.")
# Out:
# Data has been written to the 'my_table' table in the 'txt2sql' database.

# %%
df = pd.read_csv('brazilian-ecommerce\olist_order_reviews_dataset.csv')  # Replace with your CSV file path

# Step 2: Set up SQLAlchemy engine with your MySQL credentials
engine = create_engine(db_url)

# Step 3: Write the DataFrame to a new MySQL table
df.to_sql(name='order_reviews', con=engine, index=False, if_exists='replace')  # or 'append'

print("Data has been written to the 'my_table' table in the 'txt2sql' database.")
# Out:
# Data has been written to the 'my_table' table in the 'txt2sql' database.

# %%
df = pd.read_csv('brazilian-ecommerce\olist_orders_dataset.csv')  # Replace with your CSV file path

# Step 2: Set up SQLAlchemy engine with your MySQL credentials
engine = create_engine(db_url)

# Step 3: Write the DataFrame to a new MySQL table
df.to_sql(name='orders', con=engine, index=False, if_exists='replace')  # or 'append'

print("Data has been written to the 'my_table' table in the 'txt2sql' database.")
# Out:
# Data has been written to the 'my_table' table in the 'txt2sql' database.

# %%
df = pd.read_csv('brazilian-ecommerce\olist_products_dataset.csv')  # Replace with your CSV file path

# Step 2: Set up SQLAlchemy engine with your MySQL credentials
engine = create_engine(db_url)

# Step 3: Write the DataFrame to a new MySQL table
df.to_sql(name='products', con=engine, index=False, if_exists='replace')  # or 'append'

print("Data has been written to the 'my_table' table in the 'txt2sql' database.")
# Out:
# Data has been written to the 'my_table' table in the 'txt2sql' database.

# %%
df = pd.read_csv('brazilian-ecommerce\olist_sellers_dataset.csv')  # Replace with your CSV file path

# Step 2: Set up SQLAlchemy engine with your MySQL credentials
engine = create_engine(db_url)

# Step 3: Write the DataFrame to a new MySQL table
df.to_sql(name='sellers', con=engine, index=False, if_exists='replace')  # or 'append'

print("Data has been written to the 'my_table' table in the 'txt2sql' database.")
# Out:
# Data has been written to the 'my_table' table in the 'txt2sql' database.

# %%
df = pd.read_csv('brazilian-ecommerce\product_category_name_translation.csv')  # Replace with your CSV file path

# Step 2: Set up SQLAlchemy engine with your MySQL credentials
engine = create_engine(db_url)

# Step 3: Write the DataFrame to a new MySQL table
df.to_sql(name='category_translation', con=engine, index=False, if_exists='replace')  # or 'append'

print("Data has been written to the 'my_table' table in the 'txt2sql' database.")
# Out:
# Data has been written to the 'my_table' table in the 'txt2sql' database.

# %% [markdown]
# ### Indexes
# - Create below indexes so that joins are faster

# %% [markdown]
# '''CREATE INDEX idx_customer_id ON orders (customer_id(20));
#
# CREATE INDEX idx_order_id ON orders (order_id(20));
#
# ALTER TABLE orders
# MODIFY order_purchase_timestamp DATETIME;
# CREATE INDEX idx_order_purchase_timestamp ON orders (order_purchase_timestamp);
#
# CREATE INDEX idx_customer_id ON customer (customer_id(20));
#
# CREATE INDEX idx_order_items_order_id ON order_items (order_id(20));
# CREATE INDEX idx_order_items_product_id ON order_items (product_id(20));
# CREATE INDEX idx_order_items_seller_id ON order_items (seller_id(20));
#
# CREATE INDEX idx_seller_id ON sellers (seller_id(20));
#
# CREATE INDEX idx_product_id ON products (product_id(20));
# CREATE INDEX idx_product_category ON products (product_category_name(20));
#
# CREATE INDEX idx_order_reviews_order_id ON order_reviews (order_id(20));
# CREATE INDEX idx_review_score ON order_reviews (review_score);
#
# CREATE INDEX idx_order_payments_order_id ON order_payments (order_id(20));
# CREATE INDEX idx_payment_type ON order_payments (payment_type(20));
#
# CREATE INDEX idx_category_translation ON category_translation (product_category_name(20));'''

# %%
import pandas as pd
from sqlalchemy import create_engine,  text
from sqlalchemy.exc import SQLAlchemyError
from sqlalchemy.types import Integer, Float, String
from rapidfuzz import process, fuzz

engine = create_engine('mysql+mysqlconnector://root:admin123@localhost/txt2sql')
with base_engine.connect() as conn:
    # Commit is required because DB creation cannot run inside an active transaction block
    conn.execute(text("CREATE DATABASE IF NOT EXISTS txt2sql"))
    print("Database 'txt2sql' is ready!")
# Out:
# Database 'txt2sql' is ready!
